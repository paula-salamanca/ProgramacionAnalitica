# %% [markdown]
# <h2>Parcial Programación</h2>

# %% [markdown]
# <h4>Import pandas</h4>

# %%
import pandas as pd
import matplotlib.pylab as plt
import numpy as np

# %%
datos ="D:/wine_completo.csv"

# %%
df = pd.read_csv(datos)

# %% [markdown]
# 1 es vino rojo, 2 es vino blanco.

# %%
# To see what the data set looks like, we'll use the head() method.
df.head()
# Out:
#    Tipo Vino  acidez fija  acidez volatil  acidez citrica  azucar residaul  \
# 0          1          7.4            0.70            0.00              1.9
# 1          1          7.8            0.88            0.00              2.6
# 2          1          7.8            0.76            0.04              2.3
# 3          1         11.2            0.28            0.56              1.9
# 4          1          7.4            0.70            0.00              1.9
#
#    cloruros  dioxido azufre libre  total dioxido azufre  densidad    pH  \
# 0     0.076                  11.0                  34.0    0.9978  3.51
# 1     0.098                  25.0                  67.0    0.9968  3.20
# 2     0.092                  15.0                  54.0    0.9970  3.26
# 3     0.075                  17.0                  60.0    0.9980  3.16
# 4     0.076                  11.0                  34.0    0.9978  3.51
#
#    sulfatos  alcohol  quality
# 0      0.56      9.4        5
# ...

# %% [markdown]
# <h3>Identificar los valores Nulos</h3>

# %%
#Reemplazarlos
df.replace("?", np.nan, inplace = True)
df.head()
# Out:
#    Tipo Vino  acidez fija  acidez volatil  acidez citrica  azucar residaul  \
# 0          1          7.4            0.70            0.00              1.9
# 1          1          7.8            0.88            0.00              2.6
# 2          1          7.8            0.76            0.04              2.3
# 3          1         11.2            0.28            0.56              1.9
# 4          1          7.4            0.70            0.00              1.9
#
#    cloruros  dioxido azufre libre  total dioxido azufre  densidad    pH  \
# 0     0.076                  11.0                  34.0    0.9978  3.51
# 1     0.098                  25.0                  67.0    0.9968  3.20
# 2     0.092                  15.0                  54.0    0.9970  3.26
# 3     0.075                  17.0                  60.0    0.9980  3.16
# 4     0.076                  11.0                  34.0    0.9978  3.51
#
#    sulfatos  alcohol  quality
# 0      0.56      9.4        5
# ...

# %%
missing_data = df.isnull()
missing_data.head(5)
# Out:
#    Tipo Vino  acidez fija  acidez volatil  acidez citrica  azucar residaul  \
# 0      False        False           False           False            False
# 1      False        False           False           False            False
# 2      False        False           False           False            False
# 3      False        False           False           False            False
# 4      False        False           False           False            False
#
#    cloruros  dioxido azufre libre  total dioxido azufre  densidad     pH  \
# 0     False                 False                 False     False  False
# 1     False                 False                 False     False  False
# 2     False                 False                 False     False  False
# 3     False                 False                 False     False  False
# 4     False                 False                 False     False  False
#
#    sulfatos  alcohol  quality
# 0     False    False    False
# ...

# %% [markdown]
# <h4>Contar los valores nulos</h4>

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# Tipo Vino
# Tipo Vino
# False    6497
# Name: count, dtype: int64
#
# acidez fija
# acidez fija
# False    6497
# Name: count, dtype: int64
#
# acidez volatil
# acidez volatil
# False    6497
# Name: count, dtype: int64
#
# acidez citrica
# acidez citrica
# False    6497
# Name: count, dtype: int64
#
# azucar residaul
# azucar residaul
# False    6497
# Name: count, dtype: int64
#
# cloruros
# cloruros
# False    6497
# Name: count, dtype: int64
#
# dioxido azufre libre
# dioxido azufre libre
# False    6497
# Name: count, dtype: int64
#
# total dioxido azufre
# total dioxido azufre
# False    6497
# Name: count, dtype: int64
#
# densidad
# densidad
# False    6497
# Name: count, dtype: int64
#
# pH
# pH
# False    6497
# Name: count, dtype: int64
#
# sulfatos
# sulfatos
# False    6497
# Name: count, dtype: int64
#
# alcohol
# alcohol
# False    6497
# Name: count, dtype: int64
#
# quality
# quality
# False    6497
# Name: count, dtype: int64

# %% [markdown]
# <h4>Calcular la media </h4>

# %%
avg_bore=df['bore'].astype('float').mean(axis=0)
print("Average of bore:", avg_bore)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\57310\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'bore'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[69], line 1
# ...

# %% [markdown]
# <h4>Ver tipo de datos</h4>

# %%
df.dtypes
# Out:
# Tipo Vino                 int64
# acidez fija             float64
# acidez volatil          float64
# acidez citrica          float64
# azucar residaul         float64
# cloruros                float64
# dioxido azufre libre    float64
# total dioxido azufre    float64
# densidad                float64
# pH                      float64
# sulfatos                float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df.head()
# Out:
#    Tipo Vino  acidez fija  acidez volatil  acidez citrica  azucar residaul  \
# 0          1          7.4            0.70            0.00              1.9
# 1          1          7.8            0.88            0.00              2.6
# 2          1          7.8            0.76            0.04              2.3
# 3          1         11.2            0.28            0.56              1.9
# 4          1          7.4            0.70            0.00              1.9
#
#    cloruros  dioxido azufre libre  total dioxido azufre  densidad    pH  \
# 0     0.076                  11.0                  34.0    0.9978  3.51
# 1     0.098                  25.0                  67.0    0.9968  3.20
# 2     0.092                  15.0                  54.0    0.9970  3.26
# 3     0.075                  17.0                  60.0    0.9980  3.16
# 4     0.076                  11.0                  34.0    0.9978  3.51
#
#    sulfatos  alcohol  quality
# 0      0.56      9.4        5
# ...

# %% [markdown]
# Las 4 variables van a ser : Tipo Vino, calidad, alcohol, acidez citrica

# %%
bins = np.linspace(min(df["quality"]), max(df["quality"]), 4)
bins
# Out:
# array([3., 5., 7., 9.])

# %%
group_names = ['Low', 'Medium', 'High']
df['quality-binned'] = pd.cut(df['quality'], bins, labels=group_names, include_lowest=True )
df[['quality','quality-binned']].head(20)
# Out:
#     quality quality-binned
# 0         5            Low
# 1         5            Low
# 2         5            Low
# 3         6         Medium
# 4         5            Low
# 5         5            Low
# 6         5            Low
# 7         7         Medium
# 8         7         Medium
# 9         5            Low
# 10        5            Low
# 11        5            Low
# 12        5            Low
# 13        5            Low
# 14        5            Low
# 15        5            Low
# 16        7         Medium
# 17        5            Low
# 18        4            Low
# 19        6         Medium

# %%
df["quality-binned"].value_counts()
# Out:
# quality-binned
# Medium    3915
# Low       2384
# High       198
# Name: count, dtype: int64

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(df["quality-binned"])

# set x/y labels and plot title
plt.pyplot.xlabel("Calidad Vino")
plt.pyplot.ylabel("Cantidad vinos")
# Out:
# Text(0, 0.5, 'Cantidad vinos')

# %%
bins = np.linspace(min(df["alcohol"]), max(df["alcohol"]), 4)
bins
# Out:
# array([ 8. , 10.3, 12.6, 14.9])

# %%
group_names = ['Low', 'Medium', 'High']

# %%
df['alcohol-binned'] = pd.cut(df['alcohol'], bins, labels=group_names, include_lowest=True )
df[['alcohol','alcohol-binned']].head(20)
# Out:
#     alcohol alcohol-binned
# 0       9.4            NaN
# 1       9.8            NaN
# 2       9.8            NaN
# 3       9.8            NaN
# 4       9.4            NaN
# 5       9.4            NaN
# 6       9.4            NaN
# 7      10.0            NaN
# 8       9.5            NaN
# 9      10.5            NaN
# 10      9.2            NaN
# 11     10.5            NaN
# 12      9.9            NaN
# 13      9.1            NaN
# 14      9.2            NaN
# 15      9.2            NaN
# 16     10.5            NaN
# 17      9.3            NaN
# 18      9.0           High
# 19      9.2            NaN

# %%
df["alcohol-binned"].value_counts()

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(df["alcohol"])

# set x/y labels and plot title
plt.pyplot.xlabel("Cantidad alcohol")
plt.pyplot.ylabel("Cantidad vinos")
# Out:
# Text(0, 0.5, 'Cantidad vinos')

# %%
bins = np.linspace(min(df["quality"]), max(df["quality"]), 4)
bins
group_names = ['Low', 'Medium', 'High']
df['quality-binned'] = pd.cut(df['quality'], bins, labels=group_names, include_lowest=True )
df[['quality','quality-binned']].head(20)

# %%
df["alcohol-binned"].value_counts()

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(df["acidez citrica"])

# set x/y labels and plot title
plt.pyplot.xlabel("Cantidad acidez")
plt.pyplot.ylabel("Cantidad vinos")
# Out:
# Text(0, 0.5, 'Cantidad vinos')

# %% [markdown]
# Calcular Correlacón entre 4 variables

# %%
variables = df[["Tipo Vino","quality","acidez citrica","alcohol"]]
print(variables.corr())
# Out:
#                 Tipo Vino   quality  acidez citrica   alcohol
# Tipo Vino        1.000000  0.119423        0.187808  0.033129
# quality          0.119423  1.000000        0.085532  0.444319
# acidez citrica   0.187808  0.085532        1.000000 -0.010493
# alcohol          0.033129  0.444319       -0.010493  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.regplot(x="quality", y="Tipo Vino", data=df)
plt.ylim(0,)
# Out:
# (0.0, 2.05)

# %%
sns.regplot(x="acidez citrica", y="Tipo Vino", data=df)
plt.ylim(0,)
# Out:
# (0.0, 2.6975367560329317)

# %%
sns.regplot(x="alcohol", y="Tipo Vino", data=df)
plt.ylim(0,)
# Out:
# (0.0, 2.05)

# %%
sns.boxplot(x="quality", y="Tipo Vino", data=df)
# Out:
# <Axes: xlabel='quality', ylabel='Tipo Vino'>

# %%
sns.boxplot(x="acidez citrica", y="Tipo Vino", data=df)
# Out:
# <Axes: xlabel='acidez citrica', ylabel='Tipo Vino'>

# %%
sns.boxplot(x="alcohol", y="Tipo Vino", data=df)
# Out:
# <Axes: xlabel='alcohol', ylabel='Tipo Vino'>

# %%
df.describe()
# Out:
#          Tipo Vino  acidez fija  acidez volatil  acidez citrica  \
# count  6497.000000  6497.000000     6497.000000     6497.000000
# mean      1.754040     7.215307        0.339666        0.318633
# std       0.430688     1.296434        0.164636        0.145318
# min       1.000000     3.800000        0.080000        0.000000
# 25%       2.000000     6.400000        0.230000        0.250000
# 50%       2.000000     7.000000        0.290000        0.310000
# 75%       2.000000     7.700000        0.400000        0.390000
# max       2.000000    15.900000        1.580000        1.660000
#
#        azucar residaul     cloruros  dioxido azufre libre  \
# count      6497.000000  6497.000000           6497.000000
# mean          5.443235     0.056034             30.525319
# std           4.757804     0.035034             17.749400
# min           0.600000     0.009000              1.000000
# 25%           1.800000     0.038000             17.000000
# ...
